# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
import csv
import pandas as pd
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['mathtext.fontset'] = 'stix' 
plt.rcParams["font.size"] = 12
plt.rcParams['xtick.labelsize'] = 17
plt.rcParams['ytick.labelsize'] = 17 

plt.rcParams['xtick.direction'] = 'in' 
plt.rcParams['ytick.direction'] = 'in' 
plt.rcParams['axes.grid'] = True 

plt.rcParams["xtick.minor.visible"] = True  
plt.rcParams["ytick.minor.visible"] = True  
plt.rcParams['xtick.top'] = True  
plt.rcParams['ytick.right'] = True  

plt.rcParams["legend.fancybox"] = False 
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'
plt.rcParams["legend.markerscale"] = 5

# %%
def main():
    xlist = []
    for i in range(115):
        xlist.append(9*(i+1))

    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_LP_5.csv', header=None)
    NoG1_three9_vs_Distance_LP_5 = df[0].tolist()
    NoGKP_three9_vs_Distance_LP_5 = [x*3 for x in NoG1_three9_vs_Distance_LP_5]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_LP_5.csv', header=None)
    NoG1_four9_vs_Distance_LP_5 = df[0].tolist()
    NoGKP_four9_vs_Distance_LP_5 = [x*3 for x in NoG1_four9_vs_Distance_LP_5]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_LP_10.csv', header=None)
    NoG1_three9_vs_Distance_LP_10 = df[0].tolist()
    NoGKP_three9_vs_Distance_LP_10 = [x*3 for x in NoG1_three9_vs_Distance_LP_10]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_LP_10.csv', header=None)
    NoG1_four9_vs_Distance_LP_10 = df[0].tolist()
    NoGKP_four9_vs_Distance_LP_10 = [x*3 for x in NoG1_four9_vs_Distance_LP_10]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_LP_15.csv', header=None)
    NoG1_three9_vs_Distance_LP_15 = df[0].tolist()
    NoGKP_three9_vs_Distance_LP_15 = [x*3 for x in NoG1_three9_vs_Distance_LP_15]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_LP_15.csv', header=None)
    NoG1_four9_vs_Distance_LP_15 = df[0].tolist()
    NoGKP_four9_vs_Distance_LP_15 = [x*3 for x in NoG1_four9_vs_Distance_LP_15]


    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_ML_UW3_5.csv', header=None)
    NoG1_three9_vs_Distance_ML_UW3_5 = df[0].tolist()
    NoGKP_three9_vs_Distance_ML_UW3_5 = [x*3 for x in NoG1_three9_vs_Distance_ML_UW3_5]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_ML_UW3_5.csv', header=None)
    NoG1_four9_vs_Distance_ML_UW3_5 = df[0].tolist()
    NoGKP_four9_vs_Distance_ML_UW3_5 = [x*3 for x in NoG1_four9_vs_Distance_ML_UW3_5]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_ML_UW3_10.csv', header=None)
    NoG1_three9_vs_Distance_ML_UW3_10 = df[0].tolist()
    NoGKP_three9_vs_Distance_ML_UW3_10 = [x*3 for x in NoG1_three9_vs_Distance_ML_UW3_10]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_ML_UW3_10.csv', header=None)
    NoG1_four9_vs_Distance_ML_UW3_10 = df[0].tolist()
    NoGKP_four9_vs_Distance_ML_UW3_10 = [x*3 for x in NoG1_four9_vs_Distance_ML_UW3_10]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_three9_vs_Distance_ML_UW3_15.csv', header=None)
    NoG1_three9_vs_Distance_ML_UW3_15 = df[0].tolist()
    NoGKP_three9_vs_Distance_ML_UW3_15 = [x*3 for x in NoG1_three9_vs_Distance_ML_UW3_15]
    
    df = pd.read_csv('fig_data/NoG1_vs_Distance/NoG1_four9_vs_Distance_ML_UW3_15.csv', header=None)
    NoG1_four9_vs_Distance_ML_UW3_15 = df[0].tolist()
    NoGKP_four9_vs_Distance_ML_UW3_15 = [x*3 for x in NoG1_four9_vs_Distance_ML_UW3_15]

    
    
    fig = plt.figure(dpi=1200)
    fig_1 = fig.add_subplot(111)
    
    fig_1.plot(xlist, NoGKP_three9_vs_Distance_LP_5, label="$k=5$, $>0.999$", color="g")
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_LP_5, label="$k=5$, $>0.9999$", color="g")
    fig_1.plot(xlist, NoGKP_three9_vs_Distance_LP_10, label="$k=10$, $>0.999$", color="r")
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_LP_10, label="$k=10$, $>0.9999$", color="r")
    fig_1.plot(xlist, NoGKP_three9_vs_Distance_LP_15, label="$k=15$, $>0.999$", color="orange")
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_LP_15, label="$k=15$, $>0.9999$", color="orange")

    fig_1.plot(xlist, NoGKP_three9_vs_Distance_ML_UW3_5, label="$k=5$, $>0.999$ (UW3)", color="g", alpha=0.5, linestyle=':')
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_ML_UW3_5, label="$k=5$, $>0.9999$ (UW3)", color="g", alpha=0.5, linestyle=':')
    fig_1.plot(xlist, NoGKP_three9_vs_Distance_ML_UW3_10, label="$k=10$, $>0.999$ (UW3)", color="r", alpha=0.5, linestyle=':')
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_ML_UW3_10, label="$k=10$, $>0.9999$ (UW3)", color="r", alpha=0.5, linestyle=':')
    fig_1.plot(xlist, NoGKP_three9_vs_Distance_ML_UW3_15, label="$k=15$, $>0.999$ (UW3)", color="orange", alpha=0.5, linestyle=':')
    fig_1.plot(xlist, NoGKP_four9_vs_Distance_ML_UW3_15, label="$k=15$, $>0.9999$ (UW3)", color="orange", alpha=0.5, linestyle=':')
        
    fig_1.set_xlabel(r"$L_{\mathrm{total}}$ [km]")
    fig_1.set_ylabel(r"Initial number of GKP qubits [/(repeater $\cdot$ protocol run)]")
    fig_1.legend(ncol=2, bbox_to_anchor=(0, 1.1, 1., 0.102), loc=3)
    fig_1.grid(which='minor', alpha=0.2)
    fig_1.grid(which='major', alpha=0.5)
    fig_1.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    #fig_1.ticklabel_format(style="sci",  axis="y",scilimits=(0,0))
    plt.xlim(0, 1035)
    #plt.xticks(xlistgrid)
    plt.ylim(0, 2100)
    plt.show()

    fig.savefig('FIG10B04.png', bbox_inches="tight", pad_inches=0.05) 

if __name__ == "__main__":
    main()
