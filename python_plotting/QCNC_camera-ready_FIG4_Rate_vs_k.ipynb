# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
import csv
import pandas as pd
import matplotlib.ticker as mticker
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['mathtext.fontset'] = 'stix' 
plt.rcParams["font.size"] = 12
plt.rcParams['xtick.labelsize'] = 17
plt.rcParams['ytick.labelsize'] = 17 

plt.rcParams['xtick.direction'] = 'in' 
plt.rcParams['ytick.direction'] = 'in' 
plt.rcParams['axes.grid'] = True 

plt.rcParams["xtick.minor.visible"] = True  
plt.rcParams["ytick.minor.visible"] = True  
plt.rcParams['xtick.top'] = True  
plt.rcParams['ytick.right'] = True  

plt.rcParams["legend.fancybox"] = False 
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'
plt.rcParams["legend.markerscale"] = 5

# %%
#Rate (total)
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_45km.csv', header=None)
Rate_vs_k_UW3_45km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_90km.csv', header=None)
Rate_vs_k_UW3_90km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_135km.csv', header=None)
Rate_vs_k_UW3_135km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_180km.csv', header=None)
Rate_vs_k_UW3_180km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_225km.csv', header=None)
Rate_vs_k_UW3_225km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_270km.csv', header=None)
Rate_vs_k_UW3_270km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_315km.csv', header=None)
Rate_vs_k_UW3_315km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_360km.csv', header=None)
Rate_vs_k_UW3_360km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_405km.csv', header=None)
Rate_vs_k_UW3_405km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_450km.csv', header=None)
Rate_vs_k_UW3_450km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_495km.csv', header=None)
Rate_vs_k_UW3_495km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_540km.csv', header=None)
Rate_vs_k_UW3_540km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_585km.csv', header=None)
Rate_vs_k_UW3_585km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_630km.csv', header=None)
Rate_vs_k_UW3_630km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_675km.csv', header=None)
Rate_vs_k_UW3_675km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_720km.csv', header=None)
Rate_vs_k_UW3_720km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_765km.csv', header=None)
Rate_vs_k_UW3_765km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_810km.csv', header=None)
Rate_vs_k_UW3_810km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_855km.csv', header=None)
Rate_vs_k_UW3_855km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_900km.csv', header=None)
Rate_vs_k_UW3_900km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_945km.csv', header=None)
Rate_vs_k_UW3_945km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_990km.csv', header=None)
Rate_vs_k_UW3_990km = df.iloc[0].tolist()
df = pd.read_csv('fig_data/Rate_vs_k/Rate_vs_k_UW3_1035km.csv', header=None)
Rate_vs_k_UW3_1035km = df.iloc[0].tolist()

# %%
#Rate (channel)
Channel_Rate_vs_k_UW3_45km = []
Channel_Rate_vs_k_UW3_90km = []
Channel_Rate_vs_k_UW3_135km = []
Channel_Rate_vs_k_UW3_180km = []
Channel_Rate_vs_k_UW3_225km = []
Channel_Rate_vs_k_UW3_270km = []
Channel_Rate_vs_k_UW3_315km = []
Channel_Rate_vs_k_UW3_360km = []
Channel_Rate_vs_k_UW3_405km = []
Channel_Rate_vs_k_UW3_450km = []
Channel_Rate_vs_k_UW3_495km = []
Channel_Rate_vs_k_UW3_540km = []
Channel_Rate_vs_k_UW3_585km = []
Channel_Rate_vs_k_UW3_630km = []
Channel_Rate_vs_k_UW3_675km = []
Channel_Rate_vs_k_UW3_720km = []
Channel_Rate_vs_k_UW3_765km = []
Channel_Rate_vs_k_UW3_810km = []
Channel_Rate_vs_k_UW3_855km = []
Channel_Rate_vs_k_UW3_900km = []
Channel_Rate_vs_k_UW3_945km = []
Channel_Rate_vs_k_UW3_990km = []
Channel_Rate_vs_k_UW3_1035km = []

for i, val in enumerate(Rate_vs_k_UW3_45km):
    Channel_Rate_vs_k_UW3_45km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_90km):
    Channel_Rate_vs_k_UW3_90km.append(val / (i + 1))    
for i, val in enumerate(Rate_vs_k_UW3_135km):
    Channel_Rate_vs_k_UW3_135km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_180km):
    Channel_Rate_vs_k_UW3_180km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_225km):
    Channel_Rate_vs_k_UW3_225km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_270km):
    Channel_Rate_vs_k_UW3_270km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_315km):
    Channel_Rate_vs_k_UW3_315km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_360km):
    Channel_Rate_vs_k_UW3_360km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_405km):
    Channel_Rate_vs_k_UW3_405km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_450km):
    Channel_Rate_vs_k_UW3_450km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_495km):
    Channel_Rate_vs_k_UW3_495km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_540km):
    Channel_Rate_vs_k_UW3_540km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_585km):
    Channel_Rate_vs_k_UW3_585km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_630km):
    Channel_Rate_vs_k_UW3_630km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_675km):
    Channel_Rate_vs_k_UW3_675km.append(val / (i + 1))    
for i, val in enumerate(Rate_vs_k_UW3_720km):
    Channel_Rate_vs_k_UW3_720km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_765km):
    Channel_Rate_vs_k_UW3_765km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_810km):
    Channel_Rate_vs_k_UW3_810km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_855km):
    Channel_Rate_vs_k_UW3_855km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_900km):
    Channel_Rate_vs_k_UW3_900km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_945km):
    Channel_Rate_vs_k_UW3_945km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_990km):
    Channel_Rate_vs_k_UW3_990km.append(val / (i + 1))
for i, val in enumerate(Rate_vs_k_UW3_1035km):
    Channel_Rate_vs_k_UW3_1035km.append(val / (i + 1))

# %%
#Check Channel Rate
def main():
    xlist = []
    for i in range(28):
        xlist.append(i+1)
    #print(xlist)

    fig = plt.figure(dpi=200)
    fig_1 = fig.add_subplot(111)
    
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_45km, label="$45km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_90km, label="$90km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_135km, label="$135km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_180km, label="$180km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_225km, label="$225km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_270km, label="$270km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_315km, label="$315km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_360km, label="$360km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_405km, label="$405km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_450km, label="$450km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_495km, label="$495km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_540km, label="$540km$")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_585km, label="$585km$", color="#2ca02c")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_630km, label="$630km$", color="#d62728")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_675km, label="$675km$", color="#9467bd")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_720km, label="$720km$", color="#8c564b")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_765km, label="$765km$", color="#e377c2")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_810km, label="$810km$", color="#7f7f7f")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_855km, label="$855km$", color="#bcbd22")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_900km, label="$900km$", color="#17becf")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_945km, label="$945km$", color="#1f77b4")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_990km, label="$990km$", color="#ff7f0e")
    fig_1.plot(xlist, Channel_Rate_vs_k_UW3_1035km, label="$1035km$", color="#2ca02c")
 
    fig_1.set_xlabel(r"Multiplexing Level $k$")
    fig_1.set_ylabel(r"$R_{\mathrm{channel}}$ [ebit/($k\cdot$protocol run)]")
    #fig_1.legend(ncol=2, bbox_to_anchor=(0, 1.1, 1., 0.102), loc=3)
    fig_1.grid(which='minor', alpha=0.2)
    fig_1.grid(which='major', alpha=0.5)
    fig_1.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    #fig_1.ticklabel_format(style="sci",  axis="y",scilimits=(0,0))
    plt.xlim(0, 28)
    plt.ylim(0, 0.3)
    #plt.xticks(xlistgrid)
    plt.show()
    fig.savefig('QCNCFIG9B02.png', bbox_inches="tight", pad_inches=0.05) 
    
if __name__ == "__main__":
    main()
